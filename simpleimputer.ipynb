# %%
import pandas as pd
df=pd.read_excel("walmart Retail Data.xlsx")

# %%
df.head()
# Out:
#          City  Customer Age      Customer Name Customer Segment  Discount  \
# 0  McKeesport           NaN     Jessica Myrick   Small Business      0.10
# 1       Bowie           NaN     Matt Collister      Home Office      0.08
# 2        Napa           NaN  Alan Schoenberger        Corporate      0.00
# 3  Montebello           NaN  Elizabeth Moffitt         Consumer      0.08
# 4        Napa           NaN  Alan Schoenberger        Corporate      0.07
#
#    Number of Records Order Date  Order ID Order Priority  Order Quantity  ...  \
# 0                  1 2012-01-01     28774           High              32  ...
# 1                  1 2012-01-01     13729  Not Specified               9  ...
# 2                  1 2012-01-02     37537            Low               4  ...
# 3                  1 2012-01-02     44069       Critical              43  ...
# 4                  1 2012-01-02     37537            Low              43  ...
#
# ...

# %%
df.isnull().sum()
# Out:
# City                      0
# Customer Age            903
# Customer Name             0
# Customer Segment          0
# Discount                  0
# Number of Records         0
# Order Date                0
# Order ID                  0
# Order Priority            0
# Order Quantity            0
# Product Base Margin      63
# Product Category          0
# Product Container         0
# Product Name              0
# Product Sub-Category      0
# Profit                    0
# Region                    0
# Row ID                    0
# Sales                     0
# Ship Date                 0
# Ship Mode                 0
# Shipping Cost             0
# State                     0
# Unit Price                0
# Zip Code                  0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
categorical_columns=["Customer_Segment","Product Container","Product Name","Product Sub-Category","Region","Ship Mode","State"]
numerical_columns=["Customer Age","Product Base Margin"]

# %%
from sklearn.impute import SimpleImputer
numerical_imputer=SimpleImputer(strategy="mean")
categorical_imputer=SimpleImputer(strategy="most_frequent")

# %%
imputer=SimpleImputer(strategy="mean")
df['Customer Age']=imputer.fit_transform(df[['Customer Age']])

# %%
from sklearn.preprocessing import OneHotEncoder
encoder=OneHotEncoder(handle_unknown='ignore',sparse_output=False).set_output(transform='pandas')

# %%
new_df = encoder.fit_transform(df[['Product Category','Product Sub-Category','Product Container','Customer Segment','Region', 'Ship Mode', 'State']])

# %%
n
